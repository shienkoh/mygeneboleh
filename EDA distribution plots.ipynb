# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("full_data.csv")

# %%
data.head()
# Out:
#      Transcript_id          Gene_id  Position   5-mers  Read Lengths  \
# 0  ENST00000000233  ENSG00000004059       244  AAGACCA           185
# 1  ENST00000000233  ENSG00000004059       261  CAAACTG           172
# 2  ENST00000000233  ENSG00000004059       316  GAAACAG           185
# 3  ENST00000000233  ENSG00000004059       332  AGAACAT           200
# 4  ENST00000000233  ENSG00000004059       368  AGGACAA           198
#
#    right 5-mer  1-mer  2-mer  5-mer  right 1-mer  ...  Var of -1 Means  \
# 0            1      1      2      2            1  ...        24.579612
# 1            2      1      1      3            2  ...         8.939418
# 2            3      1      1      1            2  ...         2.239894
# 3            1      2      1      1            6  ...        10.310528
# 4            1      2      2      1            1  ...         7.136364
#
#    Var of 0 Means  Var of +1 Means  Var of -1 SD  Var of 0 SD  Var of +1 SD  \
# 0        7.688132         6.395905      3.415203    10.966916      8.492049
# 1       12.509130         6.249036      2.869970     1.539228      2.162594
# 2       10.320222         2.215242      1.728333     0.802647      0.644277
# 3        3.735897        12.275964      6.078633     1.952632      0.552990
# 4        4.764421         5.688583      7.563497     3.091760      1.809626
#
#    Var of -1 Dwell  Var of 0 Dwell  Var of +1 Dwell  Label
# 0         0.000029        0.000029         0.000021      0
# 1         0.000013        0.000014         0.000021      0
# 2         0.000020        0.000025         0.000020      0
# 3         0.000038        0.000021         0.000013      0
# 4         0.000051        0.000029         0.000035      0
#
# [5 rows x 53 columns]

# %%
fig, ax = plt.subplots(1, 1)
sns.kdeplot(data["Var of -1 Means"],label='-1',ax=ax)
sns.kdeplot(data["Var of 0 Means"],label='0',ax=ax)
sns.kdeplot(data["Var of +1 Means"],label='+1',ax=ax)
ax.set_xlim(0, 60)
ax.set(xlabel='Variance of Means', ylabel='Density')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(1, 1)
sns.kdeplot(data["Var of -1 Dwell"],label='-1',ax=ax)
sns.kdeplot(data["Var of 0 Dwell"],label='0',ax=ax)
sns.kdeplot(data["Var of +1 Dwell"],label='+1',ax=ax)
ax.set_xlim(0, 0.0001)
ax.set(xlabel='Variance of Dwell', ylabel='Density')
ax.legend()
plt.locator_params(nbins=5)
plt.show()

# %%
fig, ax = plt.subplots(1, 1)
sns.ecdfplot(data["Var of -1 SD"],label='-1',ax=ax)
sns.ecdfplot(data["Var of 0 SD"],label='0',ax=ax)
sns.ecdfplot(data["Var of +1 SD"],label='+1',ax=ax)
ax.set(xlabel='Variance of SD', ylabel='Density')
ax.set_xlim(0, 20)
ax.legend()
plt.show()
