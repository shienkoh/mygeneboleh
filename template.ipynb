# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (1.23.4)
# WARNING: You are using pip version 20.2.3; however, version 22.3 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (1.5.1)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/jasinchow/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3; python_version < "3.10" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas) (1.23.4)
# Requirement already satisfied: six>=1.5 in /Users/jasinchow/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: You are using pip version 20.2.3; however, version 22.3 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from sklearn) (1.1.3)
# Requirement already satisfied: scipy>=1.3.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.23.4)
# Requirement already satisfied: joblib>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.2.0)
# WARNING: You are using pip version 20.2.3; however, version 22.3 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run script3.py -ipath 'finalized_model.sav' 'evaluator.json'
# Out:
# End of Data Parsing
# End of Feature Engineering

# %%
output = pd.read_csv('data_with_preds_and_scores.csv')
output
# Out:
#      Unnamed: 0  Read Lengths  right 5-mer  1-mer  2-mer  5-mer  right 1-mer  \
# 0             0            36            3      1      1      3            1
# 1             1            38            1      3      1      2            1
# 2             2            35            1      1      2      1            2
# 3             3            35            1      1      2      1            1
# 4             4            20            1      1      2      1            1
# ..          ...           ...          ...    ...    ...    ...          ...
# 177         177           143            3      1      1      3            1
# 178         178           530            3      1      2      3            1
# 179         179           529            3      1      2      3            1
# 180         180           412            3      1      2      3            1
# 181         181           531            3      1      2      3            1
#
#      Mean of -1 Means  Mean of 0 Means  Mean of +1 Means  ...  Var of 0 Means  \
# 0          109.888889       108.716667         95.641667  ...       10.281429
# 1           84.363158        93.942105         82.560526  ...        2.811693
# 2          119.000000       124.514286         78.120000  ...       22.374790
# 3          117.857143       128.314286         81.951429  ...        9.927731
# 4          118.800000       128.400000         81.450000  ...        5.726316
# ..                ...              ...               ...  ...             ...
# 177        101.816084       101.904895         92.900699  ...        8.472441
# 178        123.647170       125.973585         91.465283  ...       16.180775
# 179        123.637051       125.971645         91.442722  ...       16.209422
# 180        123.587379       126.009709         91.430097  ...       16.695769
# 181        123.644068       125.966102         91.455744  ...       16.157339
#
#      Var of +1 Means  Var of -1 SD  Var of 0 SD  Var of +1 SD  \
# 0           2.123643      1.951242     0.228595      0.128139
# 1           2.842994      1.200388     0.381096      0.843064
# 2           5.246353      4.164183    13.244193      3.777116
# 3           7.794924      4.012301     4.681814      2.535977
# 4           5.427895      3.437820     2.402668      2.737689
# ..               ...           ...          ...           ...
# 177         8.714154      0.423323     0.699809      0.592576
# 178         4.218263      2.251647     2.188248      4.782772
# 179         4.074762      2.260119     2.188070      4.664945
# 180         4.088094      2.316763     2.290383      4.672047
# 181         4.191264      2.259885     2.187783      4.770510
#
#      Var of -1 Dwell  Var of 0 Dwell  Var of +1 Dwell  Score  Label
# 0           0.000020        0.000012         0.000010   0.00      0
# 1           0.000010        0.000010         0.000010   0.00      0
# 2           0.000042        0.000039         0.000028   0.02      0
# 3           0.000017        0.000031         0.000029   0.01      0
# 4           0.000008        0.000036         0.000020   0.02      0
# ..               ...             ...              ...    ...    ...
# 177         0.000030        0.000029         0.000014   0.10      0
# 178         0.000028        0.000027         0.000022   0.37      0
# 179         0.000028        0.000027         0.000022   0.37      0
# 180         0.000027        0.000030         0.000020   0.42      0
# 181         0.000028        0.000027         0.000022   0.37      0
#
# [182 rows x 51 columns]
